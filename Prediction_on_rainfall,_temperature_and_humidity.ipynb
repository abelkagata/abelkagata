# %% [markdown]
# <a href="https://colab.research.google.com/github/abelkagata/abelkagata/blob/main/Prediction_on_rainfall%2C_temperature_and_humidity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Installing Gradio
#
# !pip install gradio
#
# Installs the Gradio library so it can be used for building an interface.
#
# 2. Importing Libraries
#
# import numpy as np, pandas as pd
# from sklearn.ensemble import RandomForestRegressor
# import gradio as gr
#
#  `numpy` and `pandas` for data handling
#
#  `RandomForestRegressor` to train mode
#
# `gradio` to create the interface
#
#
# 3. Generating Synthetic Data
#
# data = {
#   "pressure": ..., "wind_speed": ..., "cloud_cover": ...,
#   "temperature": ..., "humidity": ..., "rainfall": ...
# }
#
# Generates 100 random data samples for weather variables.
#
#
# 4. Creating DataFrame
#
# df = pd.DataFrame(data)
#
# Stores the data in a tabular format for processing.
#
#
#
# 5. Defining Inputs and Targets
#
# x = df[["pressure", "wind_speed", "cloud_cover"]]
# y_temp = df["temperature"]
#
# - `x`: Features (input variables)
# - `y_*`: Labels (what to predict)
#
#
# 6. Training Three Models
# ```python
# model_temp = RandomForestRegressor().fit(x, y_temp)
# ```
# Trains 3 separate Random Forest models to predict:
# - Temperature
# - Humidity
# - Rainfall
#
# 7. Defining Prediction Function
#
# def predict(pressure, wind_speed, cloud_cover):
#     ...
#     return {
#         "Temperature (°C)": ..., "Humidity (%)": ..., "Rainfall (mm)": ...
#     }
# ```
# Takes 3 inputs, uses models to make predictions, returns results.
#
#
# 8. Setting Up Gradio Interface
#
# inputs = [
#     gr.Slider(...),  # Pressure
#     gr.Slider(...),  # Wind Speed
#     gr.Slider(...)   # Cloud Cover
# ]
#
# Creates sliders for user inputs in the web UI.
#
#
# 9. Launching the App
#
# gr.Interface(fn=predict, inputs=inputs, outputs=...).launch()
#
#  Connects the prediction function to the UI
# - Runs the app with a public link
#
#
# Result:
# You get a working interface to input weather data and predict temp, humidity, and rainfall instantly.

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 71.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import gradio as gr

# %%
# Example synthetic dataset (replace with real data)
data = {
    "pressure": np.random.rand(100) * 10,
    "wind_speed": np.random.rand(100) * 20,
    "cloud_cover": np.random.rand(100) * 100,
    "temperature": np.random.rand(100) * 40,
    "humidity": np.random.rand(100) * 100,
    "rainfall": np.random.rand(100) * 50
}
df = pd.DataFrame(data)

# %%
# Features (X) and targets (y)
X = df[["pressure", "wind_speed", "cloud_cover"]]
y_temp = df["temperature"]
y_humidity = df["humidity"]
y_rainfall = df["rainfall"]

# %%
# Train models
model_temp = RandomForestRegressor().fit(X, y_temp)
model_humidity = RandomForestRegressor().fit(X, y_humidity)
model_rainfall = RandomForestRegressor().fit(X, y_rainfall)

# %%
# Prediction function
def predict(pressure, wind_speed, cloud_cover):
    input_data = [[pressure, wind_speed, cloud_cover]]
    temp = model_temp.predict(input_data)[0]
    humidity = model_humidity.predict(input_data)[0]
    rainfall = model_rainfall.predict(input_data)[0]
    return {
        "Temperature (°C)": round(temp, 2),
        "Humidity (%)": round(humidity, 2),
        "Rainfall (mm)": round(rainfall, 2)
    }

# %%
# Define inputs
inputs = [
    gr.Slider(950, 1050, label="Pressure (hPa)"),
    gr.Slider(0, 50, label="Wind Speed (km/h)"),
    gr.Slider(0, 100, label="Cloud Cover (%)")
]

# %%
# Launch interface
gr.Interface(
    fn=predict,
    inputs=inputs,
    outputs="json",
    title="Weather Prediction AI",
    description="Predict Temperature, Humidity & Rainfall"
).launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://af93cf02c29245c5ba.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://af93cf02c29245c5ba.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
